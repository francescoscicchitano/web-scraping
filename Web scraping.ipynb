# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def solution(A):# Our original array 
  
    m = max(A) # Storing maximum value 
    if m < 1: 
          
        # In case all values in our array are negative 
        return 1 
    if len(A) == 1: 
          
        # If it contains only one element 
        return 2 if A[0] == 1 else 1     
    l = [0] * m 
    for i in range(len(A)): 
        if A[i] > 0: 
            if l[A[i] - 1] != 1: 
                  
                # Changing the value status at the index of our list 
                l[A[i] - 1] = 1 
    for i in range(len(l)): 
          
        # Encountering first 0, i.e, the element with least value 
        if l[i] == 0:  
            return i + 1
            # In case all values are filled between 1 and m 
    return i + 2     
  
A = [0, 1,10,35] 
print(solution(A))
# Out:
# 2

# %%
pip install beautifulsoup4
# Out:
# ...
# WARNING: You are using pip version 20.1; however, version 20.2.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
soup = BeautifulSoup("<p>Some<b>bad<i>HTML")

# %%
print(soup.prettify())
# Out:
# <p>
#  Some
#  <b>
#   bad
#   <i>
#    HTML
#   </i>
#  </b>
# </p>

# %%
soup.find(text="bad")
# Out:
# 'bad'

# %%
import requests

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!doctype html> \n<html lang="it">\n\n<head>\n    <meta charset="UTF-8">     \n    <link rel="shortcut icon" href="//www.filmtv.it/public/images/icon.ico" type="image/ico" />\n    <!-- IOS ICON -->\n    <!-- iOS 7 iPad (retina) -->\n<link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-152x152.png" sizes="152x152" rel="apple-touch-icon">\n    <!-- iOS 6 iPad (retina) -->\n<link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-144x144.png" sizes="144x144" rel="apple-touch-icon">\n    <!-- iOS 7 iPhone (retina) -->\n<link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-120x120.png" sizes="120x120" rel="apple-touch-icon">\n    <!-- iOS 6 iPhone (retina) -->\n<link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-114x114.png" sizes="114x114" rel="apple-touch-icon">\n    <!-- iOS 7 iPad -->\n<link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-76x76.png" sizes="76x76" rel="apple-touch-icon">\n    <!-- iOS 6 iPad -->\n<
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="it">
# <head>
# <meta charset="utf-8"/>
# <link href="//www.filmtv.it/public/images/icon.ico" rel="shortcut icon" type="image/ico"/>
# <!-- IOS ICON -->
# <!-- iOS 7 iPad (retina) -->
# <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <!-- iOS 6 iPad (retina) -->
# <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <!-- iOS 7 iPhone (retina) -->
# <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <!-- iOS 6 iPhone (retina) -->
# <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <!-- iOS 7 iPad -->
# <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <!-- iOS 6 iPad -->
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="it">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="//www.filmtv.it/public/images/icon.ico" rel="shortcut icon" type="image/ico"/>
#   <!-- IOS ICON -->
#   <!-- iOS 7 iPad (retina) -->
#   <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <!-- iOS 6 iPad (retina) -->
#   <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <!-- iOS 7 iPhone (retina) -->
#   <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <!-- iOS 6 iPhone (retina) -->
#   <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <!-- iOS 7 iPad -->
#   <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# ...

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html lang="it">
#  <head>
#  <meta charset="utf-8"/>
#  <link href="//www.filmtv.it/public/images/icon.ico" rel="shortcut icon" type="image/ico"/>
#  <!-- IOS ICON -->
#  <!-- iOS 7 iPad (retina) -->
#  <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#  <!-- iOS 6 iPad (retina) -->
#  <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#  <!-- iOS 7 iPhone (retina) -->
#  <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#  <!-- iOS 6 iPhone (retina) -->
#  <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#  <!-- iOS 7 iPad -->
#  <link href="//www.filmtv.it/public/images/ios-icon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#  <!-- iOS 6 iPad -->
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
# ...

# %%
paragrafo = soup.find('p', attrs = {'class': 'titolo-originale'})

# %%
paragrafo
# Out:
# <p class="titolo-originale"> Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni</p>

# %%
paragrafo.find('span').decompose()

# %%
titolo = paragrafo.text

# %%
titolo
# Out:
# ' Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni'

# %%
soup.a
# Out:
# <a href="http://www.sorrisi.com/">
# <img src="//www.filmtv.it/public/images/tv-sorrix2.png"/>
# </a>

# %%
images = soup.find('div', {"item-scheda-wrap"}).find("img")
#image_url = images['src']

# %%
images
# Out:
# <img alt="Neon Genesis Evangelion: The End of Evangelion" src="https://www.filmtv.it/imgbank/LOC/R201908/ev25.jpg">
# </img>

# %% [markdown]
# # DA QUI

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://www.filmtv.it/film/migliori/anno-2019/")

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# # OTTENGO LINK DELLE IMMAGINI

# %%
for link in soup.find_all('img'):
    print(link.get('src'))
# Out:
# //www.filmtv.it/public/images/tv-sorrix2.png
# /public/images/logo-filmtv.png
# https://www.filmtv.it/imgbank/LOC/R201908/ev25.jpg
# https://www.filmtv.it/imgbank/LOC/R201910/IRISHMAN_Vertical_RGB_Italy_IT.jpg
# https://www.filmtv.it/imgbank/LOC/R201910/locandina-l-ufficiale-e-la-spia-low.jpg
# https://www.filmtv.it/imgbank/LOC/R202002/parasite_poster_oscar.jpg
# https://www.filmtv.it/imgbank/LOC/R201907/OUTH_onesheet_Final_3Shot.jpg
# https://www.filmtv.it/imgbank/LOC/R201906/bd00.jpg
# https://www.filmtv.it/imgbank/LOC/R201905/locandina-il-traditore-low.jpg
# https://www.filmtv.it/imgbank/LOC/R201912/Richard_Jewell_-_Poster_-_Dal_16_gennaio_al_cinema.jpg
# https://www.filmtv.it/imgbank/LOC/R202008/Monos_poster_agosto_web.jpg
# https://www.filmtv.it/imgbank/LOC/R201910/Joker_Poster-Italia.jpg
# https://www.filmtv.it/imgbank/LOC/R201904/dolor.jpg
# https://www.filmtv.it/imgbank/LOC/R202001/unnamed-2.jpg
# https://www.filmtv.it/imgbank/LOC/R202002/as.jpg
# ...

# %% [markdown]
# # Ottengo tag alt dalle immagini che corrisponde al titolo

# %%
for link in soup.find_all('img'):
    print(link.get('alt'))
# Out:
# None
# logo FilmTv
# Neon Genesis Evangelion: The End of Evangelion
# The Irishman
# L'ufficiale e la spia
# Parasite
# C'era una volta a... Hollywood
# Better Days
# Il traditore
# Richard Jewell
# Monos - Un gioco da ragazzi
# Joker
# Dolor y gloria
# La vita nascosta - Hidden Life
# A Sun
# Buttiamo giù l'uomo
# Alla mia piccola Sama
# Storia di un matrimonio
# The Lighthouse
# I miserabili
# Sulle ali dell'avventura
# Diamanti grezzi
# Locandina Easy Living
# Locandina Endless
# Locandina Genesis 2.0
# Locandina Guida romantica a posti perduti
# Locandina Il giorno sbagliato
# Locandina Mai per sempre
# Locandina PadreNostro
# Locandina Paolo Conte, via con me
# Locandina Undine - Un amore per sempre
# Locandina Waiting for the Barbarians
# maso
# Scarlett Blu
# elle driver
# Immorale
# bradipo68
# supadany
# eloiseshf
# Carlo Ceruti
# sasso67
# miss brown
# Kurtisonic
# Lehava
# None

# %% [markdown]
# # Ottengo tag specifici

# %%
tag = soup.findAll('ul', {'info cf'})

# %%
testo = []
for a in tag:
    testo.append(a.text)

# %%
testo
# Out:
# ["\nAnimazione Giappone 2019 durata 90' ",
#  "\nBiografico USA 2019 durata 210' ",
#  "\nDrammatico Francia, Italia 2019 durata 126' ",
#  "\nDrammatico Corea del Sud 2019 durata 132' ",
#  "\nDrammatico USA 2019 durata 165' ",
#  "\nDrammatico Cina 2019 durata 138' ",
#  "\nDrammatico Italia 2019 durata 135' ",
#  "\nDrammatico USA 2019 durata 129' ",
#  "\nDrammatico Colombia 2019 durata 102' ",
#  "\nDrammatico USA 2019 durata 122' ",
#  "\nCommedia Spagna 2019 durata 108' ",
#  "\nDrammatico USA, Italia, Germania, Austria 2019 durata 173' ",
#  "\nDrammatico Taiwan 2019 durata 155' ",
#  "\nDrammatico USA 2019 durata 90' ",
#  "\nDocumentario Gran Bretagna 2019 durata 95' ",
#  "\nDrammatico USA 2019 durata 136' ",
#  "\nDrammatico Canada 2019 durata 110' ",
#  "\nDrammatico Francia 2019 durata 103' ",
#  "\nAvventura Francia 2019 durata 113' ",
#  "\nThriller USA 2019 durata 135' "]

# %% [markdown]
# # PER SCARICARE IMMAGINI

# %%
file = open("sample_image.png", "wb")
immagine = requests.get('https://www.filmtv.it/imgbank/LOC/R201908/ev25.jpg')
file.write(immagine.content)
file.close()

# %% [markdown]
# # Utilizzo pandas per creare csv

# %%
# orologi e vestiti ()
